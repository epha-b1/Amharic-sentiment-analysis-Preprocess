# %% [markdown]
# ## Import the dataset

# %%
import pandas as pd

df_train = pd.read_csv("Dataset/train.csv")
df_test = pd.read_csv("Dataset/test.csv")

df_train.head()
# Out:
#    Unnamed: 0             tweet_id sentiment  \
# 0           0  1213084822521950209   neutral
# 1           1  1213011490372038656   neutral
# 2           2  1213763702715043840     mixed
# 3           3  1213764224356421633   neutral
# 4           4  1212766574337150976  positive
#
#                                                tweet
# 0                                                NaN
# 1      ልዩ የተፈጥሮ ገፅታ \n *****\n\nየምስራቅ አፍሪካ የውሃ ማማ ጮቄ
# 2  @AbbaSheger ማንም ቢሆን የሀገሩን ጥቅም አሳልፎ አይሰጥም። ያ መላ...
# 3  ብ/ጄ አሳምነው ጽጌ ከምክትል ጠ/ሚ ደመቀ ጋር በሱዳን ጉብኝት አልበሽር ...
# 4                                                NaN

# %% [markdown]
# ## Find out the number of output classes

# %%
print(df_train['sentiment'].unique())
# Out:
# ['neutral' 'mixed' 'positive' 'negative']

# %% [markdown]
# ## Visualize the data distribution

# %%
df_train['sentiment'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
df_test['sentiment'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7511 entries, 0 to 7510
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  7511 non-null   int64
#  1   tweet_id    7511 non-null   int64
#  2   sentiment   7511 non-null   object
#  3   tweet       6282 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 234.8+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 939 entries, 0 to 938
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  939 non-null    int64
#  1   tweet_id    939 non-null    int64
#  2   sentiment   939 non-null    object
#  3   tweet       790 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 29.5+ KB
